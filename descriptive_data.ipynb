# %% [markdown]
# # Análise Exploratória dos Dados
#
# Este projeto realiza uma análise exploratória dos acidentes registrados pela
# Polícia Rodoviária Federal (PRF).
#
# ## Etapas da análise
#
# - Inspeção dos dados
# - Estatística descritiva
# - Análise univariada
# - Análise de variáveis categóricas
# - Análise de variáveis numéricas
# - Análise bivariada
# - Análise multivariada
# - Análise de correlação
# - Correlação de Pearson
#
# ## Fonte dos dados
#
# **Polícia Rodoviária Federal (PRF)**
# https://www.gov.br/prf/pt-br/acesso-a-informacao/dados-abertos/dados-abertos-da-prf
#
# ---
#
# ## Bibliotecas utilizadas

# %%
# !pip install cartopy
# !pip install geopandas
# !pip install folium
# !pip install geodatasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 77.2 MB/s eta 0:00:00
# ...

# %%
# Manipulação e análise de dados
import pandas as pd
import numpy as np
# Visualização
import matplotlib.pyplot as plt
import seaborn as sns
# Manipulação de textos
import textwrap
# Análise geoespacial
import geopandas as gpd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
# Funções matemáticas
import math

# %% [markdown]
# Leitura dos dados

# %%
from google.colab import drive
import pandas as pd

# Monta o Google Drive
drive.mount('/content/drive')

import pandas as pd

df = pd.read_csv(
    "/content/drive/MyDrive/Curso_Data_Science/3_semana/datatran2026.csv",
    sep=";",
    encoding="latin1",
    decimal=","
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Understanding the dataset

print(f"Linhas | Rows: {df.shape[0]:,}")
print(f"Colunas | Columns: {df.shape[1]}")
print(f"Duplicados | Duplicates: {df.duplicated().sum():,}")

resumo_dados = pd.DataFrame({
    "Tipo": df.dtypes,
    "Não nulos": df.notna().sum(),
    "Nulos": df.isna().sum(),
    "Valores únicos": df.nunique()
})

display(resumo_dados)
# Out:
# Linhas | Rows: 5,806
# Colunas | Columns: 30
# Duplicados | Duplicates: 0
#                            Tipo  Não nulos  Nulos  Valores únicos
# id                        int64       5806      0            5806
# data_inversa             object       5806      0              31
# dia_semana               object       5806      0               7
# horario                  object       5806      0             759
# uf                       object       5806      0              27
# br                        int64       5806      0              99
# km                      float64       5806      0            2478
# municipio                object       5806      0            1208
# causa_acidente           object       5806      0              61
# tipo_acidente            object       5806      0              17
# classificacao_acidente   object       5805      1               3
# fase_dia                 object       5806      0               4
# ...

# %%
# Descriptive statistics for numerical variables
display(df.describe().T.round(2))
# Out:
#                  count       mean      std        min        25%        50%  \
# id              5806.0  746264.17  2091.08  742884.00  744534.25  746211.50
# br              5806.0     209.43   128.13       0.00     101.00     156.00
# km              5806.0     261.05   227.72       0.00      73.00     194.25
# pessoas         5806.0       2.74     2.56       1.00       2.00       2.00
# mortos          5806.0       0.09     0.38       0.00       0.00       0.00
# feridos_leves   5806.0       0.96     1.36       0.00       0.00       1.00
# feridos_graves  5806.0       0.28     0.69       0.00       0.00       0.00
# ilesos          5806.0       1.13     1.94       0.00       0.00       1.00
# ignorados       5806.0       0.36     0.78       0.00       0.00       0.00
# feridos         5806.0       1.24     1.56       0.00       1.00       1.00
# veiculos        5806.0       1.94     1.09       1.00       1.00       2.00
# ...

# %%
# Dataset time range
# Converts the date column to datetime format
df["data_inversa"] = pd.to_datetime(
    df["data_inversa"],
    dayfirst=True,
    errors="coerce"
)

# Identifies the time period covered by the dataset
data_inicial = df["data_inversa"].min()
data_final = df["data_inversa"].max()

duracao_dias = (data_final - data_inicial).days

resumo_periodo = pd.DataFrame({
    "Informação | Information": [
        "Data inicial | Start date",
        "Data final | End date",
        "Período total | Total period"
    ],
    "Valor | Value": [
        data_inicial.strftime("%d/%m/%Y"),
        data_final.strftime("%d/%m/%Y"),
        f"{duracao_dias:,} dias"
    ]
})

display(resumo_periodo)
# Out:
#        Informação | Information Valor | Value
# 0     Data inicial | Start date    01/01/2026
# 1         Data final | End date    01/12/2026
# 2  Período total | Total period      334 dias
